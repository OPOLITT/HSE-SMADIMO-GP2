# %%
import pandas as pd 
import requests as req

# %%
tmdb_api_key = "2d803f0bf1fc809a3131688e280c4cd1"

# %%
search_url = "https://api.themoviedb.org/3/search/movie"

params = {
    "api_key": tmdb_api_key,
    "query": "White Chicks",
    "language": "en-US"
}

headers = {
    "accept": "application/json"
}

response = req.get(search_url, params=params, headers=headers)

response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/85k0kaoRgGmF6ACq0M61AFxhjLN.jpg',
#    'genre_ids': [35, 80],
#    'id': 12153,
#    'original_language': 'en',
#    'original_title': 'White Chicks',
#    'overview': 'Two FBI agent brothers, Marcus and Kevin Copeland, accidentally foil a drug bust. To avoid being fired they accept a mission escorting a pair of socialites to the Hamptons--but when the girls are disfigured in a car accident, they refuse to go. Left without options, Marcus and Kevin decide to pose as the sisters, transforming themselves from black men into rich white women.',
#    'popularity': 14.5759,
#    'poster_path': '/aHTUpo45qy9QYIOnVITGGqLoVcA.jpg',
#    'release_date': '2004-06-23',
#    'title': 'White Chicks',
#    'video': False,
#    'vote_average': 6.931,
#    'vote_count': 4442},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [35],
#    'id': 488844,
#    'original_language': 'en',
# ...

# %%
add_tmdb_info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 add_tmdb_info(req)
#
# Cell In[8], line 2, in add_tmdb_info(row)
#       1 def add_tmdb_info(row) -> list:
# ----> 2     json_film = row.to_dict()
#       4     # parameter = 'tv' if json_film['type']=='TV Show' else 'movie'
#       5     search_url = f'https://api.themoviedb.org/3/search/movie'
#
# AttributeError: module 'requests' has no attribute 'to_dict'
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/anastasia/anaconda3/lib/python3.11/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/anastasia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
# ...

# %% [markdown]
# ## Тестовый пайплайн
#
# ### Вход: pd.DataFrame
# ### Выход: pd.DataFrame (c дополнительными полями)
#
# Данный код используется для тестирования общего пайплана, чтобы протустировать код на данных < 100;

# %%
movies_titles = [
    
]

# %% [markdown]
# ## Базовый пайплайн
#
# ### Вход: pd.DataFrame
# ### Выход: pd.DataFrame (c дополнительными полями)

# %% [markdown]
# Пример по использованию api - https://github.com/18Months/themoviedb-api/blob/master/README.md
#
# Документация - https://developer.themoviedb.org/reference/account-add-favorite
